# %%
import librosa
import librosa.display
import IPython.display
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm
import pandas as pd

# %%
# Out:
# ../STFT-CNN/data/101_1b1_Al_sc_Meditron.wav
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-b32eb116d321> in <module>
#       5     audio_path = '../STFT-CNN/data/'+filename[step]
#       6     print(audio_path[0])
# ----> 7     signal, sr = librosa.load(audio_path[0], sr=44100 , res_type = 'kaiser_best')
#       8     mfcc = librosa.feature.mfcc(y=signal, sr=sr)
#       9     mfcc_delta2 = librosa.feature.delta(mfcc, order=2)
#
# C:\ProgramData\Anaconda3\lib\site-packages\librosa\core\audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     117
#     118     y = []
# --> 119     with audioread.audio_open(os.path.realpath(path)) as input_file:
#     120         sr_native = input_file.samplerate
#     121         n_channels = input_file.channels
#
# C:\ProgramData\Anaconda3\lib\site-packages\audioread\__init__.py in audio_open(path)
#      78     from . import rawread
#      79     try:
# ---> 80         return rawread.RawAudioFile(path)
#      81     except DecodeError:
#      82         pass
#
# C:\ProgramData\Anaconda3\lib\site-packages\audioread\rawread.py in __init__(self, filename)
#      59     """
#      60     def __init__(self, filename):
# ---> 61         self._fh = open(filename, 'rb')
#      62
#      63         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\kkyon\\OneDrive\\Desktop\\STFT-CNN\\data\\101_1b1_Al_sc_Meditron.wav'

# %%
filename = np.array(pd.read_csv('data/SC_file_name.csv'))
answer = np.array(pd.read_csv('data/SC_answer.csv'))
size_ = 2

for step in range(5):
    audio_path = 'data/wav/'+filename[step]
    #print(audio_path[0])
    y, sr = librosa.load(audio_path[0])
    D = np.abs(librosa.stft(y))
    librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max))
    print(answer[step])
    #plt.title(audio_path[0])
    #plt.figure(figsize=(0.78*size_,0.78*size_)) #size 56x56
    #plt.show()
    
    '''split the file name'''
    tmp_name=str(audio_path[0])
    tmp_name=tmp_name.split(".")
    tmp_name=tmp_name[0]
    tmp_name=tmp_name.split("/")
    print(tmp_name[2])
    
    #왜 이미지가 저렇게 저장되지
    if answer[step] == 0 :
        plt.savefig(path+'train_0/'+''.join(tmp_name[2])+'.png')
    else:
        plt.savefig(path+'train_1/'+''.join(tmp_name[2])+'.png')
    
    
    '''
    Test할것 train 할 것 나눠
    20%
    '''
# Out:
# [0]
# 101_1b1_Al_sc_Meditron
# [0]
# 101_1b1_Pr_sc_Meditron
# [1]
# 102_1b1_Ar_sc_Meditron
# [0]
# 104_1b1_Al_sc_Litt3200
# [0]
# 104_1b1_Ar_sc_Litt3200
